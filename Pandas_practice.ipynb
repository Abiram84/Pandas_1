# %% [markdown]
# <a href="https://colab.research.google.com/github/Abiram84/Pandas_1/blob/main/Pandas_practice.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df0 = pd.read_csv("/content/Data.csv")
df0
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-3-4d6a92ad9ddb> in <module>
# ----> 1 df0 = pd.read_csv("/content/Data.csv")
#       2 df0
#
# /usr/local/lib/python3.7/dist-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     309                     stacklevel=stacklevel,
#     310                 )
# --> 311             return func(*args, **kwargs)
#     312
#     313         return wrapper
#
# ...

# %%
data = {'Fruits':['Orange','Apple',"Grapes",'Banana'], 'Quantity':[5,8,4,10], 'Price':[40, 80, 20, 15]}
df2 = pd.DataFrame(data)
df2
# Out:
#    Fruits  Quantity  Price
# 0  Orange         5     40
# 1   Apple         8     80
# 2  Grapes         4     20
# 3  Banana        10     15

# %%
data = [['Orange', 5, 40],['Apple', 8, 80],['Grapes', 4, 20],['Banana', 10, 14]]
df1 = pd.DataFrame(data, columns = ['Fruit_Name', 'Price', 'Quantity'])
df1
# Out:
#   Fruit_Name  Price  Quantity
# 0     Orange      5        40
# 1      Apple      8        80
# 2     Grapes      4        20
# 3     Banana     10        14

# %%
row = {'Fruit_Name': 'Peach', 'Quantity':4, 'Price':100 }
df1 = df1.append(row, ignore_index = True)
df1
# Out:
#   Fruit_Name  Price  Quantity
# 0     Orange      5        40
# 1      Apple      8        80
# 2     Grapes      4        20
# 3     Banana     10        14
# 4      Peach    100         4

# %%
print(len(df1.index))
df1.loc[0] = ['Orange', 6, 40, 6*40]
df1
# Out:
# 5
#    Fruits  Kg_quan  Unit_Price  Total_Price
# 0  Orange        6          40          240
# 1   Apple        8          80          640
# 2  Grapes        4          20           80
# 3  Banana       10          14          140
# 4   Peach      100           4          400

# %%
df1['tot_Price'] = df1['Price'] * df1['Quantity']
df1

# %%
df1.columns = ['Fruits', 'Kg_quan', 'Unit_Price', 'Total_Price']
df1

# %%
df1.index = ['f2','f4','f6','f5','f3','f1']
df1 = df1.sort_index(ascending = False,axis = 1)
df1
# Out:
#     Unit_Price  Total_Price  Kg_quan       Fruits
# f2           8          640       80        Apple
# f4         100         2000       20  Water_Melon
# f6          10          140       14       Banana
# f5         100          400        4        Peach
# f3           6          240       40       Orange
# f1           4           80       20       Grapes

# %%
s1 = pd.Series(['Realme', 'Redmi', 'Apple', 'Nothing'], name='Topic')
s2 = pd.Series([35000, 10000, 80000, 25000], name='Cost')
print(s1)
print(s2)
df2 = pd.merge(s1,s2,left_index= True,right_index=True)
df2
# Out:
# 0     Realme
# 1      Redmi
# 2      Apple
# 3    Nothing
# Name: Topic, dtype: object
# 0    35000
# 1    10000
# 2    80000
# 3    25000
# Name: Cost, dtype: int64
#      Topic   Cost
# 0   Realme  35000
# 1    Redmi  10000
# 2    Apple  80000
# 3  Nothing  25000

# %%
df3 = s1.to_frame()
df3
# Out:
#      Topic
# 0   Realme
# 1    Redmi
# 2    Apple
# 3  Nothing

# %%
df4 = s1.to_frame().reset_index()
df4
# Out:
#    index    Topic
# 0      0   Realme
# 1      1    Redmi
# 2      2    Apple
# 3      3  Nothing

# %%
df3.iloc[5]
df3.loc[5]
# Out:
# sepal_length            4.6
# sepal_width             3.4
# petal_length            1.4
# petal_width             0.3
# class           Iris-setosa
# Name: 5, dtype: object

# %%
df4 = pd.read_csv('http://archive.ics.uci.edu/ml/machine-learning-databases/iris/iris.data')
df4.columns = ['sepal_length', 'sepal_width', 'petal_length', 'petal_width', 'class']
df4
# Out:
#      sepal_length  sepal_width  petal_length  petal_width           class
# 0             4.9          3.0           1.4          0.2     Iris-setosa
# 1             4.7          3.2           1.3          0.2     Iris-setosa
# 2             4.6          3.1           1.5          0.2     Iris-setosa
# 3             5.0          3.6           1.4          0.2     Iris-setosa
# 4             5.4          3.9           1.7          0.4     Iris-setosa
# ..            ...          ...           ...          ...             ...
# 144           6.7          3.0           5.2          2.3  Iris-virginica
# 145           6.3          2.5           5.0          1.9  Iris-virginica
# 146           6.5          3.0           5.2          2.0  Iris-virginica
# 147           6.2          3.4           5.4          2.3  Iris-virginica
# 148           5.9          3.0           5.1          1.8  Iris-virginica
#
# [149 rows x 5 columns]

# %%
df4.loc[[102,118,123,124],['petal_length','petal_width']]
# Out:
#      petal_length  petal_width
# 102           5.6          1.8
# 118           5.0          1.5
# 123           5.7          2.1
# 124           6.0          1.8

# %%
df4.plot()
plt.show()

# %%
df4.plot(kind = 'scatter', x = 'petal_length', y = 'petal_width')
plt.show()

# %%
df4['sepal_length'].plot(kind='hist')
plt.show()
